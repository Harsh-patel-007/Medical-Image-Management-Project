# %%
# verify.py

import sqlite3

DATABASE_NAME = 'medical_images.db'

def view_database_contents():
    """
    Connects to the database and prints all the records from the 'images' table.
    """
    try:
        conn = sqlite3.connect(DATABASE_NAME)
        cursor = conn.cursor()
        
        print(f"--- Contents of '{DATABASE_NAME}' ---")
        
        # SELECT * means "get all columns". FROM images specifies the table.
        cursor.execute("SELECT * FROM images")
        
        # cursor.fetchall() gets all the rows from the result.
        all_rows = cursor.fetchall()
        
        if not all_rows:
            print("The database is empty.")
            return

        # Print a header
        print(f"{'ID':<5} | {'Patient ID':<15} | {'Study Date':<15} | {'Modality':<10} | {'File Path'}")
        print("-" * 80)
        
        # Loop through each row and print its contents
        for row in all_rows:
            print(f"{row[0]:<5} | {row[1]:<15} | {row[2]:<15} | {row[3]:<10} | {row[4]}")

    except sqlite3.OperationalError:
        print(f"Error: Database file '{DATABASE_NAME}' not found. Please run organizer.py first.")
    finally:
        if 'conn' in locals():
            conn.close()

# --- Call the function to view the data ---
view_database_contents()
# Out:
# --- Contents of 'medical_images.db' ---
# ID    | Patient ID      | Study Date      | Modality   | File Path
# --------------------------------------------------------------------------------
# 1     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-004.dcm
# 2     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-005.dcm
# 3     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-006.dcm
# 4     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-007.dcm
# 5     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-008.dcm
# 6     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-009.dcm
# 7     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-010.dcm
# 8     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-011.dcm
# 9     | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-012.dcm
# 10    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-013.dcm
# 11    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-014.dcm
# 12    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-015.dcm
# 13    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-016.dcm
# 14    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-017.dcm
# 15    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-018.dcm
# 16    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-019.dcm
# 17    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-020.dcm
# 18    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-021.dcm
# 19    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-022.dcm
# 20    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-023.dcm
# 21    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-024.dcm
# 22    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-025.dcm
# 23    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-026.dcm
# 24    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-027.dcm
# 25    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-028.dcm
# 26    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-029.dcm
# 27    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-033.dcm
# 28    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-034.dcm
# 29    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-035.dcm
# 30    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-036.dcm
# 31    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-037.dcm
# 32    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-038.dcm
# 33    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-039.dcm
# 34    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-040.dcm
# 35    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-041.dcm
# 36    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-042.dcm
# 37    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-043.dcm
# 38    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-044.dcm
# 39    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-045.dcm
# 40    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-046.dcm
# 41    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-047.dcm
# 42    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-048.dcm
# 43    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-049.dcm
# 44    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-050.dcm
# 45    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-051.dcm
# 46    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-052.dcm
# 47    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-053.dcm
# 48    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-054.dcm
# 49    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-055.dcm
# 50    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-056.dcm
# 51    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-057.dcm
# 52    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-058.dcm
# 53    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-059.dcm
# 54    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-060.dcm
# 55    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-061.dcm
# 56    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-062.dcm
# 57    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-063.dcm
# 58    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-064.dcm
# 59    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-065.dcm
# 60    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-066.dcm
# 61    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-067.dcm
# 62    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-068.dcm
# 63    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-069.dcm
# 64    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-070.dcm
# 65    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-071.dcm
# 66    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-072.dcm
# 67    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-073.dcm
# 68    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-074.dcm
# 69    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-075.dcm
# 70    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-076.dcm
# 71    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-077.dcm
# 72    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-078.dcm
# 73    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-079.dcm
# 74    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-080.dcm
# 75    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-081.dcm
# 76    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-082.dcm
# 77    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-083.dcm
# 78    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-084.dcm
# 79    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-085.dcm
# 80    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-086.dcm
# 81    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-087.dcm
# 82    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-088.dcm
# 83    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-089.dcm
# 84    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-090.dcm
# 85    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-091.dcm
# 86    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-092.dcm
# 87    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-093.dcm
# 88    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-094.dcm
# 89    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-095.dcm
# 90    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-096.dcm
# 91    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-097.dcm
# 92    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-098.dcm
# 93    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-099.dcm
# 94    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-100.dcm
# 95    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-101.dcm
# 96    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-102.dcm
# 97    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-103.dcm
# 98    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-104.dcm
# 99    | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-105.dcm
# 100   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-106.dcm
# 101   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-107.dcm
# 102   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-108.dcm
# 103   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-109.dcm
# 104   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-110.dcm
# 105   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-111.dcm
# 106   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-112.dcm
# 107   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-113.dcm
# 108   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-114.dcm
# 109   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-115.dcm
# 110   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-116.dcm
# 111   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-117.dcm
# 112   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-118.dcm
# 113   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-119.dcm
# 114   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-120.dcm
# 115   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-121.dcm
# 116   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-122.dcm
# 117   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-123.dcm
# 118   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-124.dcm
# 119   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-125.dcm
# 120   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-126.dcm
# 121   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-127.dcm
# 122   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-128.dcm
# 123   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-129.dcm
# 124   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-130.dcm
# 125   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-131.dcm
# 126   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-132.dcm
# 127   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-133.dcm
# 128   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-134.dcm
# 129   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-135.dcm
# 130   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-136.dcm
# 131   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-137.dcm
# 132   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-138.dcm
# 133   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-139.dcm
# 134   | TCGA-CS-5396    | 20010302        | MR         | dicom_images\1-140.dcm
